# %% [markdown]
# ## 1. Object Detection (One Image)

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=yolov10/weights/"YoloV10n (1).pt" source=test_images/2.jpg
# Out:
# Ultralytics YOLOv8.2.86 🚀 Python-3.11.0 torch-2.0.1 CPU (Apple M3)
# YOLOv10n summary (fused): 285 layers, 2,762,608 parameters, 63,840 gradients, 8.6 GFLOPs
#
# image 1/1 /Users/richardjiang/Downloads/2 - Competitions & Research/Microsoft AI Talent Program/YOLO-Learning/YOLOv10/test_images/2.jpg: 640x640 3 17s, 76.1ms
# Speed: 4.8ms preprocess, 76.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## 2. License Detection (Images)

# %%
# !yolo task=detect mode=train epochs=20 batch=16 plots=True model=yolov10/weights/"YoloV10s (1).pt" device="mps" data=custom_data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.87 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.86 🚀 Python-3.11.0 torch-2.0.1 MPS (Apple M3)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=yolov10/weights/"YoloV10s (1).pt" source=test_images_1/veh2.jpg
# Out:
# Ultralytics YOLOv8.2.86 🚀 Python-3.11.0 torch-2.0.1 CPU (Apple M3)
# YOLOv10s summary (fused): 293 layers, 8,096,880 parameters, 86,880 gradients, 24.8 GFLOPs
#
# image 1/1 /Users/richardjiang/Downloads/2 - Competitions & Research/Microsoft AI Talent Program/YOLO-Learning/YOLOv10/test_images_1/veh2.jpg: 512x640 1 2, 126.4ms
# Speed: 2.9ms preprocess, 126.4ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## 3. License Detection (Videos)

# %%
# !yolo task=detect mode=predict conf=0.30 save=True model=yolov10/weights/"YoloV10s (1).pt" source=b.mp4
# Out:
# Ultralytics YOLOv8.2.86 🚀 Python-3.11.0 torch-2.0.1 CPU (Apple M3)
# YOLOv10s summary (fused): 293 layers, 8,096,880 parameters, 86,880 gradients, 24.8 GFLOPs
#
# video 1/1 (frame 1/348) /Users/richardjiang/Downloads/2 - Competitions & Research/Microsoft AI Talent Program/YOLO-Learning/YOLOv10/b.mp4: 384x640 4 0s, 10 2s, 2 7s, 99.0ms
# video 1/1 (frame 2/348) /Users/richardjiang/Downloads/2 - Competitions & Research/Microsoft AI Talent Program/YOLO-Learning/YOLOv10/b.mp4: 384x640 2 0s, 9 2s, 2 7s, 97.4ms
# video 1/1 (frame 3/348) /Users/richardjiang/Downloads/2 - Competitions & Research/Microsoft AI Talent Program/YOLO-Learning/YOLOv10/b.mp4: 384x640 3 0s, 9 2s, 1 7, 96.7ms
# video 1/1 (frame 4/348) /Users/richardjiang/Downloads/2 - Competitions & Research/Microsoft AI Talent Program/YOLO-Learning/YOLOv10/b.mp4: 384x640 2 0s, 7 2s, 1 7, 94.7ms
# ...
